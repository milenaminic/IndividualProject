# %% [markdown]
# -CLEANING-

# %% [markdown]
# CUSTOMER TABLE

# %%
import pandas as pd

#Uploading data
path = 'CustomerData_csv.csv'
df_customer = pd.read_csv (path)
df_customer
# Out:
#      USERID GENDER         DOB  COUNTRY    EDUCATION          HOBBY
# 0     42570      F    7/4/1986   Guinea               Ultra running
# 1     32100      F    1/2/1975  Uruguay     Bachelor     Beekeeping
# 2     28150      F  10/25/1996   Mexico  High school          Other
# 3     37070      M    5/5/1998   Rwanda  High school  Ultra running
# 4     37610      F  10/31/2001   Sweden  High school        Puzzles
# ..      ...    ...         ...      ...          ...            ...
# 569   34310      M   7/19/1973    Malta     Bachelor      Laser tag
# 570   43630      M   9/15/1978  Andorra                     Running
# 571   18950      M   7/12/1990  Romania     Bachelor     Embroidery
# 572   25410      M    6/5/1988   France  High school  Ultra running
# 573   37720      N   8/20/1965  Croatia                     Macrame
#
# [574 rows x 6 columns]

# %%
df_customer.head(5)
# Out:
#    USERID GENDER         DOB  COUNTRY    EDUCATION          HOBBY
# 0   42570      F    7/4/1986   Guinea               Ultra running
# 1   32100      F    1/2/1975  Uruguay     Bachelor     Beekeeping
# 2   28150      F  10/25/1996   Mexico  High school          Other
# 3   37070      M    5/5/1998   Rwanda  High school  Ultra running
# 4   37610      F  10/31/2001   Sweden  High school        Puzzles

# %%
distinct_customers = df_customer['USERID'].nunique()
distinct_customers
# Out:
# 574

# %%
import pandas as pd
path = 'C:/Users/jet769/Downloads/ItemData.csv'
df_item= pd.read_csv (path)

# Check for duplicate rows
duplicate_rows = df_item[df_item.duplicated()]

# Display the duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#          ITEM CATEGORY    COLOR  PURCHASEPRICE  SALEPRICE
# 116    233042      TIE   SILVER        1968.62       2170
# 156    271249    DRESS     PINK        1969.47       3550
# 232    296066    JEANS     PINK         145.65        220
# 314    250267   JACKET     GOLD         665.68        500
# 355    279517    DRESS     GOLD        1468.47       1620
# ...       ...      ...      ...            ...        ...
# 57869  397362      TIE     GOLD         173.32        260
# 57870  282039    DRESS     GOLD        1146.32       1720
# 57871  271678  PAJAMAS     GOLD         321.07        400
# 57872  223331    DRESS     PINK        1528.73       1680
# 57873  322534    DRESS  RAINBOW        1730.81       2600
#
# [32775 rows x 5 columns]

# %%
df_item.drop_duplicates(inplace=True)
print(df_item)
# Out:
#          ITEM CATEGORY    COLOR  PURCHASEPRICE  SALEPRICE
# 0      116302     BELT     GOLD          49.33         70
# 1      491105   JACKET     GOLD         390.30        290
# 2      281740    DRESS   VIOLET        1016.14       1520
# 3      237683   GLOVES  RAINBOW        1574.78       1970
# 4      430083     BELT  RAINBOW         640.33       1150
# ...       ...      ...      ...            ...        ...
# 57834  173047    JEANS     PINK        1350.06       1490
# 57848  166742   JACKET   VIOLET         319.41        570
# 57852  351472    DRESS     GOLD        1805.19       2710
# 57861  280973   JACKET  RAINBOW         161.84        180
# 57866  161815     BELT  RAINBOW        1530.36       2750
#
# [25099 rows x 5 columns]

# %%
duplicate_rows = df_item[df_item.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ITEM, CATEGORY, COLOR, PURCHASEPRICE, SALEPRICE]
# Index: []

# %%
import numpy as np
df_customer.replace(" ", np.nan, inplace = True)
df_customer.head(5)
# Out:
#    USERID GENDER         DOB  COUNTRY    EDUCATION          HOBBY
# 0   42570      F    7/4/1986   Guinea          NaN  Ultra running
# 1   32100      F    1/2/1975  Uruguay     Bachelor     Beekeeping
# 2   28150      F  10/25/1996   Mexico  High school          Other
# 3   37070      M    5/5/1998   Rwanda  High school  Ultra running
# 4   37610      F  10/31/2001   Sweden  High school        Puzzles

# %% [markdown]
# ITEM TABLE

# %%
path = 'C:/Users/jet769/Desktop/Individual project/DA Case_Q12023/Raw data/ItemData_csv.csv'
df_item = pd.read_csv (path)
df_item
# Out:
#          ITEM CATEGORY    COLOR   SUPLID  PURCHASEPRICE  SALEPRICE
# 0      383985    JEANS   VIOLET                 1246.02     1870.0
# 1      327162    DRESS  RAINBOW  38007OO         285.19      360.0
# 2      154080    SHIRT     PINK  30779XX         170.11      190.0
# 3      244638    SCARF     GOLD  26023OO         973.02     1460.0
# 4      320285    DRESS   SILVER  44207LL         696.35     1040.0
# ...       ...      ...      ...      ...            ...        ...
# 59995  473126    SCARF     GOLD  38007TT         661.38      500.0
# 59996  455589    DRESS     GOLD  30779XX        1881.00     1410.0
# 59997  182459     BELT     GOLD  17732BB         709.69      780.0
# 59998  298744      TIE  RAINBOW  40392UU         978.44     1220.0
# 59999  499373    JEANS   VIOLET  40392UU         734.85      810.0
#
# [60000 rows x 6 columns]

# %%
duplicates = df_item.duplicated()
print(duplicates)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59995    False
# 59996    False
# 59997    False
# 59998    False
# 59999    False
# Length: 60000, dtype: bool

# %%
df_item.replace(" ", np.nan, inplace = True)
df_item.head(5)
# Out:
#      ITEM CATEGORY    COLOR   SUPLID  PURCHASEPRICE  SALEPRICE
# 0  383985    JEANS   VIOLET      NaN        1246.02     1870.0
# 1  327162    DRESS  RAINBOW  38007OO         285.19      360.0
# 2  154080    SHIRT     PINK  30779XX         170.11      190.0
# 3  244638    SCARF     GOLD  26023OO         973.02     1460.0
# 4  320285    DRESS   SILVER  44207LL         696.35     1040.0

# %% [markdown]
# TRANSACTION TABLE

# %%
path = 'C:/Users/jet769/Desktop/Individual project/DA Case_Q12023/Raw data/TransactionsData_csv.csv'
df_transaction = pd.read_csv (path)
df_transaction
# Out:
#         USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0      39400.0     CHROME     KEVIN  116302.0           2.0       3.0
# 1      41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 2      22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 3      10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 4      39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
# ...        ...        ...       ...       ...      ...  ...       ...
# 59995  30630.0     SAFARI     SENDI  397362.0      YES  1.0      11.0
# 59996  24650.0     CHROME        NO  282039.0      YES  1.0       4.0
# 59997  44710.0   EXPLORER  ISABELLA  271678.0       NO  4.0      19.0
# 59998  29160.0  MOBILEAPP    BIANCA  223331.0      YES  NaN       4.0
# 59999  47450.0  MOBILEAPP  ISABELLA  322534.0      YES  NaN      29.0
#
#                PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  \
# ...

# %%
df_transaction.replace(" ", np.nan, inplace = True)
df_transaction.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 2  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 3  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 4  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  TRACKNO  \
# 0  VISA/MASTERCARD       NaN       3.0     6/3/2018     NO     NaN   302395
# 1           PAYPAL       NaN       1.0     5/2/2018     NO     4.0   487677
# 2              NaN         E       4.0    7/10/2018     NO     2.0   488880
# 3           PAYPAL         B       4.0     3/7/2018     NO     NaN   419436
# 4              NaN         C       2.0    6/28/2018    YES     4.0   381257
#
#     TIMESTAMP
# 0  2:20:21 PM
# 1  7:26:44 PM
# 2  4:48:04 PM
# 3  4:48:04 PM
# 4  2:27:35 AM

# %%
print(df_transaction["PAYMENT"].value_counts())
# Out:
# PAYMENT
# PAYPAL             12091
# APPLE PAY          12080
# VISA/MASTERCARD    11961
# AMEX               11767
# Name: count, dtype: int64

# %%
#replaceing all NaN values where payment is done with any payments metod (in original table of transaction we had empty rows for "PURCHASE")
condition = (df_transaction['PURCHASE']== 'Nan') & (
    (df_transaction['PAYMENT'] == 'PAYPAL') | 
    (df_transaction['PAYMENT'] == 'APPLE PAY ') | 
    (df_transaction['PAYMENT'] == 'VISA/MASTERCARD') | 
    (df_transaction['PAYMENT'] == 'AMEX')
    )
df_transaction['PURCHASE'] = np.where(condition, 'YES', df_transaction['PURCHASE'])

# %%
df_transaction.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 2  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 3  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 4  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  TRACKNO  \
# 0  VISA/MASTERCARD       NaN       3.0     6/3/2018     NO     NaN   302395
# 1           PAYPAL       NaN       1.0     5/2/2018     NO     4.0   487677
# 2              NaN         E       4.0    7/10/2018     NO     2.0   488880
# 3           PAYPAL         B       4.0     3/7/2018     NO     NaN   419436
# 4              NaN         C       2.0    6/28/2018    YES     4.0   381257
#
#     TIMESTAMP
# 0  2:20:21 PM
# 1  7:26:44 PM
# 2  4:48:04 PM
# 3  4:48:04 PM
# 4  2:27:35 AM

# %%
#add a column 'AMOUNT before discount' and calculate it as QTY * PURCHASEPRICE

merged_df = df_transaction.merge(df_item, left_on='ITEM', right_on='ITEM', how='left')

merged_df['AMOUNT before %'] = merged_df['QTY'] * merged_df['SALEPRICE']

merged_df.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 2  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 4  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS  ... REVIEW RATING  TRACKNO  \
# 0  VISA/MASTERCARD       NaN       3.0  ...     NO    NaN   302395
# 1  VISA/MASTERCARD       NaN       3.0  ...     NO    NaN   302395
# 2           PAYPAL       NaN       1.0  ...     NO    4.0   487677
# 3           PAYPAL       NaN       1.0  ...     NO    4.0   487677
# 4              NaN         E       4.0  ...     NO    2.0   488880
#
#     TIMESTAMP CATEGORY   COLOR   SUPLID PURCHASEPRICE  SALEPRICE  \
# 0  2:20:21 PM     BELT    GOLD  23981OO         49.33       70.0
# ...

# %%
#add a column 'amount after discount'
merged_df['AMOUNT after %'] = merged_df['AMOUNT before %'] * (1 - merged_df['DISCOUNT'] / 100)
merged_df.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 2  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 4  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS  ... RATING TRACKNO   TIMESTAMP  \
# 0  VISA/MASTERCARD       NaN       3.0  ...    NaN  302395  2:20:21 PM
# 1  VISA/MASTERCARD       NaN       3.0  ...    NaN  302395  2:20:21 PM
# 2           PAYPAL       NaN       1.0  ...    4.0  487677  7:26:44 PM
# 3           PAYPAL       NaN       1.0  ...    4.0  487677  7:26:44 PM
# 4              NaN         E       4.0  ...    2.0  488880  4:48:04 PM
#
#    CATEGORY   COLOR   SUPLID PURCHASEPRICE SALEPRICE  AMOUNT before %  \
# ...

# %%
#Finding more duplicates rows
duplicate_rows = merged_df[merged_df.duplicated()]

if duplicate_rows.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows found:")
    print(duplicate_rows)
# Out:
# Duplicate rows found:
#          USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 11      14820.0     CHROME  ISABELLA  373676.0      YES  5.0       9.0
# 133     11520.0     CHROME        NO  153846.0      YES  4.0       4.0
# 267     37150.0  MOBILEAPP     KENZA  364745.0      YES  5.0      27.0
# 305     39990.0  MOBILEAPP        NO  421841.0      NaN  5.0      28.0
# 369     21040.0     SAFARI     KEVIN  159384.0      YES  1.0      27.0
# ...         ...        ...       ...       ...      ...  ...       ...
# 119902  14510.0     CHROME     KEVIN  205599.0      YES  3.0       7.0
# 119914  33780.0     SAFARI  ISABELLA  283222.0      YES  1.0      14.0
# 119920  35810.0     CHROME        NO  174334.0      YES  NaN       3.0
# 119966  24390.0     CHROME     KEVIN  303775.0      YES  5.0      26.0
# 119970  18280.0  MOBILEAPP     KEVIN  231950.0      YES  4.0      13.0
#
#                 PAYMENT WAREHOUSE  SHIPDAYS  ... RATING TRACKNO    TIMESTAMP  \
# ...

# %%
df_no_duplicates = merged_df.drop_duplicates()

# %%
duplicate_rows = df_no_duplicates[df_no_duplicates.duplicated()]

if duplicate_rows.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows found:")
    print(duplicate_rows)
# Out:
# No duplicate rows found.

# %%
df_no_duplicates.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 2  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 4  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS  ... RATING TRACKNO   TIMESTAMP  \
# 0  VISA/MASTERCARD       NaN       3.0  ...    NaN  302395  2:20:21 PM
# 1  VISA/MASTERCARD       NaN       3.0  ...    NaN  302395  2:20:21 PM
# 2           PAYPAL       NaN       1.0  ...    4.0  487677  7:26:44 PM
# 3           PAYPAL       NaN       1.0  ...    4.0  487677  7:26:44 PM
# 4              NaN         E       4.0  ...    2.0  488880  4:48:04 PM
#
#    CATEGORY   COLOR   SUPLID PURCHASEPRICE SALEPRICE  AMOUNT before %  \
# ...

# %%
df_sales = df_no_duplicates

# %%
df_sales = df_sales.drop('SUPLID', axis=1)

# %%
duplicate_rows = df_sales[df_sales.duplicated()]

if duplicate_rows.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows found:")
    print(duplicate_rows)
# Out:
# Duplicate rows found:
#          USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1       39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3       41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5       22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7       10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9       39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
# ...         ...        ...       ...       ...      ...  ...       ...
# 119990  30630.0     SAFARI     SENDI  397362.0      YES  1.0      11.0
# 119992  24650.0     CHROME        NO  282039.0      YES  1.0       4.0
# 119994  44710.0   EXPLORER  ISABELLA  271678.0       NO  4.0      19.0
# 119996  29160.0  MOBILEAPP    BIANCA  223331.0      YES  NaN       4.0
# 119998  47450.0  MOBILEAPP  ISABELLA  322534.0      YES  NaN      29.0
#
#                 PAYMENT WAREHOUSE  SHIPDAYS  ... REVIEW RATING  TRACKNO  \
# ...

# %%
df_sales = duplicate_rows.drop_duplicates()
df_sales.head()
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS  ... REVIEW RATING  TRACKNO  \
# 1  VISA/MASTERCARD       NaN       3.0  ...     NO    NaN   302395
# 3           PAYPAL       NaN       1.0  ...     NO    4.0   487677
# 5              NaN         E       4.0  ...     NO    2.0   488880
# 7           PAYPAL         B       4.0  ...     NO    NaN   419436
# 9              NaN         C       2.0  ...    YES    4.0   381257
#
#     TIMESTAMP CATEGORY    COLOR PURCHASEPRICE  SALEPRICE  AMOUNT before %  \
# 1  2:20:21 PM     BELT     GOLD         49.33       70.0            140.0
# ...

# %%
excel_file = 'data.xlsx'
df_sales.to_excel(excel_file, sheet_name='Sheet1', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as data.xlsx

# %%
df_sales.to_excel(r'C:\Users\jet769\Desktop\Individual project\DA Case_Q12023.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jet769\Desktop\Individual project\DA Case_Q12023\Individual Project\individual_project.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jet769/Desktop/Individual%20project/DA%20Case_Q12023/Individual%20Project/individual_project.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> df_sales.to_excel(r'C:\Users\jet769\Desktop\Individual project\DA Case_Q12023.xlsx', index=False)
#
# File c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
# ...

# %% [markdown]
# EXTRACT DATA & MORE CLEANING

# %%
df_sales.replace(" ", np.nan, inplace = True)
df_sales.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS  ... REVIEW RATING  TRACKNO  \
# 1  VISA/MASTERCARD       NaN       3.0  ...     NO    NaN   302395
# 3           PAYPAL       NaN       1.0  ...     NO    4.0   487677
# 5              NaN         E       4.0  ...     NO    2.0   488880
# 7           PAYPAL         B       4.0  ...     NO    NaN   419436
# 9              NaN         C       2.0  ...    YES    4.0   381257
#
#     TIMESTAMP CATEGORY    COLOR PURCHASEPRICE  SALEPRICE  AMOUNT before %  \
# 1  2:20:21 PM     BELT     GOLD         49.33       70.0            140.0
# ...

# %%
df_item = df_sales[['ITEM', 'CATEGORY','COLOR', 'PURCHASEPRICE','SALEPRICE']]
df_transaction = df_sales[['USERID','WEBBROWSER','PPC_ADD', 'ITEM', 'PURCHASE','QTY', 'DISCOUNT','PAYMENT','WAREHOUSE','SHIPDAYS','DELIVERYDATE','REVIEW','TRACKNO','TIMESTAMP','AMOUNT before %','AMOUNT after %']]
df_item.head(5)
# Out:
#        ITEM CATEGORY    COLOR  PURCHASEPRICE  SALEPRICE
# 1  116302.0     BELT     GOLD          49.33       70.0
# 3  491105.0   JACKET     GOLD         390.30      290.0
# 5  281740.0    DRESS   VIOLET        1016.14     1520.0
# 7  237683.0   GLOVES  RAINBOW        1574.78     1970.0
# 9  430083.0     BELT  RAINBOW         640.33     1150.0

# %%
df_transaction.head(50)
# Out:
#       USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1    39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3    41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5    22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7    10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9    39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
# 13   21620.0  MOBILEAPP    BIANCA  282910.0      YES  4.0      28.0
# 15   35480.0  MOBILEAPP     KEVIN  428588.0      YES  5.0      11.0
# 17   30400.0  MOBILEAPP  ISABELLA  115600.0       NO  5.0      20.0
# 19   35940.0  MOBILEAPP        NO  435062.0      YES  2.0      19.0
# 21   33100.0     SAFARI        NO  487166.0      YES  4.0       7.0
# 23   14830.0     CHROME     SENDI  279231.0       NO  1.0      30.0
# 25   26430.0     CHROME  ISABELLA  369607.0      YES  3.0       NaN
# 27   19930.0  MOBILEAPP    BIANCA  444331.0      YES  4.0      30.0
# ...

# %%
df_transaction.to_excel(r'C:\Users\jet769\Desktop\Individual project\DA Case_Q12023.xlsx', index=False)

# %%
print(df_transaction["DELIVERYDATE"].head(50))
# Out:
# 1        6/3/2018
# 3        5/2/2018
# 5       7/10/2018
# 7        3/7/2018
# 9       6/28/2018
# 13      1/10/2018
# 15       6/8/2018
# 17      2/12/2018
# 19      1/10/2018
# 21      6/28/2018
# 23      7/15/2018
# 25       6/3/2018
# 27      3/23/2018
# 29       6/8/2018
# 31      8/27/2018
# 33       4/5/2018
# 35       3/7/2018
# 37      12/3/2018
# 39      7/29/2018
# 41      5/18/2018
# 43      7/29/2018
# 45      6/28/2018
# 47       4/5/2018
# 49      3/23/2018
# 51      7/10/2018
# 53      12/3/2018
# 55      1/13/2018
# 57      3/23/2018
# 59       6/8/2018
# 61      3/28/2018
# 63      8/25/2018
# 65       4/5/2018
# 67       6/3/2018
# 69      7/19/2018
# 71      7/25/2018
# 73       1/9/2018
# 75      5/20/2018
# 77      7/19/2018
# 79      6/12/2018
# 81      8/27/2018
# 83      3/28/2018
# 85     12/13/2018
# 87      2/26/2018
# 89      12/3/2018
# 91       3/2/2018
# 93      7/10/2018
# 95      4/28/2018
# 97     12/13/2018
# 99      8/25/2018
# 101     7/25/2018
# ...

# %%
null_count = df_transaction["DELIVERYDATE"].isnull().sum()
print("Number of null values in 'DELIVERYDATE' column: {}".format(null_count))
# Out:
# Number of null values in 'DELIVERYDATE' column: 1991

# %%
excel_file = 'TransactionData.xlsx'
df_transaction.to_excel(excel_file, sheet_name='Sheet1', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as TransactionData.xlsx

# %%
df_item.to_excel(r'C:\Users\jet769\Desktop\Individual project\DA Case_Q12023.xlsx', index=False)

# %%
excel_file = 'ItemData.xlsx'
df_item.to_excel(excel_file, sheet_name='Sheet1', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as ItemData.xlsx

# %% [markdown]
# -CREATING CALENDAR TABLE for analysis in Qlik-

# %%
# Create a list of dates for the year 2018
start_date = pd.to_datetime('01/01/2018')
end_date = pd.to_datetime('31/12/2018')
date_range = pd.date_range(start_date, end_date)

# Create a DataFrame with Date, Month (full name), and Month Abbreviation columns
df = pd.DataFrame({
    'Date': date_range,
    'Month': date_range.strftime('%B'),  # Full month names
    'MonthAbbr': date_range.strftime('%b'),  # Month abbreviations
    'Weekday': date_range.strftime('%A'),
    'Year': date_range.strftime('%Y')    # Year
    
})
df['MonthYear'] = df['Date'].dt.strftime('%m-%Y')
# Define a dictionary to map month abbreviations to numeric values
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Add the 'MonthNbr' column based on 'MonthAbbr' using the map function
df['MonthNbr'] = df['MonthAbbr'].map(month_mapping)

# Display the DataFrame
print(df)
# Out:
#           Date     Month MonthAbbr    Weekday  Year MonthYear  MonthNbr
# 0   2018-01-01   January       Jan     Monday  2018   01-2018         1
# 1   2018-01-02   January       Jan    Tuesday  2018   01-2018         1
# 2   2018-01-03   January       Jan  Wednesday  2018   01-2018         1
# 3   2018-01-04   January       Jan   Thursday  2018   01-2018         1
# 4   2018-01-05   January       Jan     Friday  2018   01-2018         1
# ..         ...       ...       ...        ...   ...       ...       ...
# 360 2018-12-27  December       Dec   Thursday  2018   12-2018        12
# 361 2018-12-28  December       Dec     Friday  2018   12-2018        12
# 362 2018-12-29  December       Dec   Saturday  2018   12-2018        12
# 363 2018-12-30  December       Dec     Sunday  2018   12-2018        12
# 364 2018-12-31  December       Dec     Monday  2018   12-2018        12
#
# [365 rows x 7 columns]
# ...

# %%
#I will add MonthNbr column

# %%
excel_file = 'CalendarData.xlsx'
df.to_excel(excel_file, sheet_name='Calendar', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as CalendarData.xlsx

# %%
df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# Convert the 'Date' column back to the "Y-M-D" format
df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

df_transaction.head(5)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_19172\3351500706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# C:\Users\jet769\AppData\Local\Temp\ipykernel_19172\3351500706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# ...

# %%
#add column TRANSACTION DATE
from datetime import datetime, timedelta

# Convert 'DeliveryDate' column to datetime
df_transaction['DELIVERYDATE'] = pd.to_datetime(df_transaction['DELIVERYDATE'])

# Calculate the transaction date by subtracting 'ShipDays' (converted to integers) from 'DeliveryDate'
df_transaction['TRANSACTIONDATE'] = df_transaction.apply(lambda row: row['DELIVERYDATE'] - timedelta(days=int(row['SHIPDAYS'])) if not pd.isna(row['SHIPDAYS']) else None, axis=1)


df_transaction.head(5)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_19172\1670850293.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['DELIVERYDATE'] = pd.to_datetime(df_transaction['DELIVERYDATE'])
# C:\Users\jet769\AppData\Local\Temp\ipykernel_19172\1670850293.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['TRANSACTIONDATE'] = df_transaction.apply(lambda row: row['DELIVERYDATE'] - timedelta(days=int(row['SHIPDAYS'])) if not pd.isna(row['SHIPDAYS']) else None, axis=1)
# ...

# %%
df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# Convert the 'Date' column back to the "Y-M-D" format
df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

df_transaction.head(5)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\3351500706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\3351500706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# ...

# %%
excel_file = 'TransactionData.xlsx'
df_transaction.to_excel(excel_file, sheet_name='Transaction', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as TransactionData.xlsx

# %%
path = 'C:/Users/jet769/Desktop/Individual project/DA Case_Q12023/Trans.Data/TransactionsData_excel_csv.csv'
transaction_original_df = pd.read_csv (path)
transaction_original_df
# Out:
#         USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0      39400.0     CHROME     KEVIN  116302.0           2.0       3.0
# 1      41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 2      22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 3      10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 4      39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
# ...        ...        ...       ...       ...      ...  ...       ...
# 59995  30630.0     SAFARI     SENDI  397362.0      YES  1.0      11.0
# 59996  24650.0     CHROME        NO  282039.0      YES  1.0       4.0
# 59997  44710.0   EXPLORER  ISABELLA  271678.0       NO  4.0      19.0
# 59998  29160.0  MOBILEAPP    BIANCA  223331.0      YES  NaN       4.0
# 59999  47450.0  MOBILEAPP  ISABELLA  322534.0      YES  NaN      29.0
#
#                PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  RATING  \
# ...

# %%
#Replacing missing (null) values in df_transaction with values from transaction_original_df based on matching user IDs and item values


merged_df = df_transaction.merge(transaction_original_df, on =["USERID","ITEM", "TRACKNO","WEBBROWSER","PPC_ADD","PURCHASE","QTY","DISCOUNT","PAYMENT","WAREHOUSE","SHIPDAYS","REVIEW"],  how="left")
merged_df.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 0  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 1  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 2  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 3  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 4  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE_x REVIEW  TRACKNO  \
# 0  VISA/MASTERCARD       NaN       3.0       6/3/2018     NO   302395
# 1           PAYPAL       NaN       1.0       5/2/2018     NO   487677
# 2              NaN         E       4.0      7/10/2018     NO   488880
# 3           PAYPAL         B       4.0       3/7/2018     NO   419436
# 4              NaN         C       2.0      6/28/2018    YES   381257
#
#   TIMESTAMP_x  AMOUNT before %  AMOUNT after % DELIVERYDATE_y  RATING  \
# 0  2:20:21 PM            140.0           135.8            NaN     NaN
# ...

# %%
#Using fillna() method to replace missing values in the original DataFrame ("df_transaction") with values from the merged DataFrame transaction_original_df
df_transaction["DELIVERYDATE"].fillna(merged_df["DELIVERYDATE_x"], inplace=True)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\369652294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction["DELIVERYDATE"].fillna(merged_df["DELIVERYDATE_x"], inplace=True)

# %%
null_count = df_transaction["DELIVERYDATE"].isnull().sum()
print("Number of null values in 'DELIVERYDATE' column: {}".format(null_count))
# Out:
# Number of null values in 'DELIVERYDATE' column: 1066

# %%
df_transaction.head(5)
# Out:
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  TRACKNO  \
# 1  VISA/MASTERCARD       NaN       3.0     6/3/2018     NO   302395
# 3           PAYPAL       NaN       1.0     5/2/2018     NO   487677
# 5              NaN         E       4.0    7/10/2018     NO   488880
# 7           PAYPAL         B       4.0     3/7/2018     NO   419436
# 9              NaN         C       2.0    6/28/2018    YES   381257
#
#     TIMESTAMP  AMOUNT before %  AMOUNT after %
# 1  2:20:21 PM            140.0           135.8
# 3  7:26:44 PM            580.0           504.6
# ...

# %%
#droping the columns from the merged DataFrame that no longer need
merged_df.drop(columns=["DELIVERYDATE_y"], inplace=True)

# %%
df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# Convert the 'Date' column back to the "Y-M-D" format
df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')

df_transaction.head(5)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\3351500706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['DELIVERYDATE'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\3351500706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# ...

# %%
excel_file = 'Transaction_new2.xlsx'
df_transaction.to_excel(excel_file, sheet_name='Transaction', index=False)

print(f'DataFrame saved as {excel_file}')
# Out:
# DataFrame saved as Transaction_new2.xlsx

# %% [markdown]
# -EXPLORING INSIGHT-

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Is there any correlatin between Sales Performance of Coats and Discount?

# %%
#Add a new column REVENUE in Transacion table
df_transaction['REVENUE']= df_transaction['QTY'] * df_transaction['AMOUNT after %']
df_transaction.head(5)
# Out:
# C:\Users\jet769\AppData\Local\Temp\ipykernel_16980\990965237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transaction['REVENUE']= df_transaction['QTY'] * df_transaction['AMOUNT after %']
#     USERID WEBBROWSER   PPC_ADD      ITEM PURCHASE  QTY  DISCOUNT  \
# 1  39400.0     CHROME     KEVIN  116302.0      NaN  2.0       3.0
# 3  41390.0     CHROME  ISABELLA  491105.0       NO  2.0      13.0
# 5  22840.0  MOBILEAPP     KEVIN  281740.0      YES  1.0      17.0
# 7  10650.0  MOBILEAPP     KEVIN  237683.0       NO  4.0      21.0
# 9  39690.0     CHROME    BIANCA  430083.0      YES  1.0       4.0
#
#            PAYMENT WAREHOUSE  SHIPDAYS DELIVERYDATE REVIEW  TRACKNO  \
# ...

# %%
from scipy import stats

correlation = df_transaction['REVENUE'].corr(df_transaction['DISCOUNT'])
print(correlation)
# Out:
# -0.0876758434573202

# %% [markdown]
# there are not correlation in general between REVENUE and DISCOUNT. Let's count correlation between REVENUE where COAT category and discount

# %%
# Filter the 'Item' table to include only 'COAT' category
coat_items_df = df_item[df_item['CATEGORY'] == 'COAT']

df_merged = pd.merge (coat_items_df, df_transaction, on = 'ITEM', how = 'inner')
df_merged.head(5)
# Out:
#        ITEM CATEGORY    COLOR  PURCHASEPRICE  SALEPRICE   USERID WEBBROWSER  \
# 0  131915.0     COAT  RAINBOW          63.14       90.0  39220.0  MOBILEAPP
# 1  131915.0     COAT  RAINBOW          63.14       90.0  33780.0  MOBILEAPP
# 2  131915.0     COAT  RAINBOW          63.14       90.0  45830.0     CHROME
# 3  131915.0     COAT  RAINBOW          63.14       90.0  39220.0  MOBILEAPP
# 4  131915.0     COAT  RAINBOW          63.14       90.0  33780.0  MOBILEAPP
#
#   PPC_ADD PURCHASE  QTY  ...  WAREHOUSE SHIPDAYS DELIVERYDATE  REVIEW TRACKNO  \
# 0  BIANCA      NaN  3.0  ...          C      1.0   2018-02-03      NO  464841
# 1   KEVIN      YES  5.0  ...          A      7.0          NaT     YES  307064
# 2   KEVIN      YES  1.0  ...          B      1.0          NaT      NO  376236
# 3  BIANCA      NaN  3.0  ...          C      1.0   2018-02-03      NO  464841
# 4   KEVIN      YES  5.0  ...          A      7.0          NaT     YES  307064
#
# ...

# %%
unique_categories = df_merged['COLOR'].unique()
unique_categories
# Out:
# array(['RAINBOW', 'GOLD', 'SILVER', 'VIOLET', 'PINK'], dtype=object)

# %%
unique_categories = df_merged['WEBBROWSER'].unique()
unique_categories
# Out:
# array(['MOBILEAPP', 'CHROME', 'SAFARI', 'EXPLORER', nan], dtype=object)

# %%
unique_categories = df_merged['PPC_ADD'].unique()
unique_categories
# Out:
# array(['BIANCA', 'KEVIN', 'KENZA', 'ISABELLA', 'NO', 'SENDI', nan],
#       dtype=object)

# %%
sns.boxplot(x="PPC_ADD", y="REVENUE", data=df_merged)
# Out:
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='PPC_ADD', ylabel='REVENUE'>

# %%
correlation = df_merged['PURCHASEPRICE'].corr(df_merged['DISCOUNT'])
print(correlation)
# Out:
# 0.008979975893622174

# %%
correlation = df_merged['SALEPRICE'].corr(df_merged['DISCOUNT'])
print(correlation)
# Out:
# 0.010060748466731717

# %%
sns.regplot(x="DISCOUNT", y="REVENUE", data=df_merged)
plt.ylim(0,)
# Out:
# (0.0, 79128.0)

# %%
df_merged.describe()
# Out:
#                 ITEM  PURCHASEPRICE    SALEPRICE        USERID          QTY  \
# count    3240.000000    3240.000000  3240.000000   3238.000000  2977.000000
# mean   304453.291049    1001.240130  1364.212963  30226.022236     3.099093
# min    100663.000000       1.400000     0.000000  10060.000000     1.000000
# 25%    191770.250000     523.050000   680.000000  19790.000000     1.000000
# 50%    320441.000000    1031.870000  1355.000000  30580.000000     4.000000
# 75%    403589.000000    1482.030000  2030.000000  40290.000000     5.000000
# max    498632.000000    1993.130000  3550.000000  49850.000000     5.000000
# std    117700.995392     560.308204   805.472252  11712.632711     1.631322
#
#           DISCOUNT     SHIPDAYS         DELIVERYDATE        TRACKNO  \
# count  3200.000000  2894.000000                   18    3240.000000
# mean     15.790000     5.033518  2018-06-22 21:20:00  401028.741975
# min       0.000000     1.000000  2018-02-03 00:00:00  300052.000000
# ...

# %%
merged_table = df_merged.merge(df_customer, on = 'USERID', how= 'inner')
merged_table
# Out:
#           ITEM CATEGORY    COLOR  PURCHASEPRICE  SALEPRICE   USERID  \
# 0     131915.0     COAT  RAINBOW          63.14       90.0  39220.0
# 1     131915.0     COAT  RAINBOW          63.14       90.0  39220.0
# 2     131915.0     COAT  RAINBOW          63.14       90.0  39220.0
# 3     170785.0     COAT     GOLD         901.87     1350.0  39220.0
# 4     170785.0     COAT     GOLD         901.87     1350.0  39220.0
# ...        ...      ...      ...            ...        ...      ...
# 3233  308585.0     COAT     GOLD        1393.26     2090.0  48260.0
# 3234  461296.0     COAT   SILVER        1851.62     2310.0  35650.0
# 3235  461296.0     COAT   SILVER        1851.62     2310.0  35650.0
# 3236  275058.0     COAT     GOLD        1451.48     2180.0  41630.0
# 3237  152143.0     COAT     GOLD        1919.04     2400.0  35710.0
#
#      WEBBROWSER   PPC_ADD PURCHASE  QTY  ...    TIMESTAMP AMOUNT before %  \
# 0     MOBILEAPP    BIANCA      NaN  3.0  ...   2:46:13 AM           270.0
# ...

# %%
# Create a boxplot
plt.figure(figsize=(12, 6))  # Optional: Set the figure size
sns.boxplot(x="COUNTRY", y="REVENUE", data=merged_table)

plt.xticks(rotation=45)

# Optional: Customize the plot further (e.g., add labels and titles)
plt.xlabel("Country")
plt.ylabel("Revenue")
plt.title("Boxplot of Revenue by Country")

# Show the plot
plt.show()
# Out:
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\jet769\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
